# %% [markdown]
# <a href="https://colab.research.google.com/github/hananfarizta/Python-Data_Wrangling_DQLab/blob/main/Data_Wrangling_DQLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Read Data with Pandas

# %%
import pandas as pd

csv_data = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/shopping_data.csv")

csv_data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# ## Get Data

# %%
csv_data.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
csv_data["Age"]
# Out:
# 0      19
# 1      21
# 2      20
# 3      23
# 4      31
#        ..
# 195    35
# 196    45
# 197    32
# 198    32
# 199    30
# Name: Age, Length: 200, dtype: int64

# %%
csv_data.iloc[4]
# Out:
# CustomerID                     5
# Genre                     Female
# Age                           31
# Annual Income (k$)            17
# Spending Score (1-100)        40
# Name: 4, dtype: object

# %%
csv_data["Age"].iloc[1]
# Out:
# 21

# %%
print("Cuplikan dataset: ")
csv_data.head()
# Out:
# Cuplikan dataset:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
print("Menampilkan data ke 5 sampai kurang dari 10: ")
csv_data["Age"].iloc[5:10]
# Out:
# Menampilkan data ke 5 sampai kurang dari 10:
# 5    22
# 6    35
# 7    23
# 8    64
# 9    30
# Name: Age, dtype: int64

# %%
print("Menampilkan data ke 5 sampai kurang dari 10: ")
csv_data.iloc[5:10]
# Out:
# Menampilkan data ke 5 sampai kurang dari 10:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %%
csv_data.describe(include="all")
# Out:
#         CustomerID   Genre         Age  Annual Income (k$)  \
# count   200.000000     200  200.000000          200.000000
# unique         NaN       2         NaN                 NaN
# top            NaN  Female         NaN                 NaN
# freq           NaN     112         NaN                 NaN
# mean    100.500000     NaN   38.850000           60.560000
# std      57.879185     NaN   13.969007           26.264721
# min       1.000000     NaN   18.000000           15.000000
# 25%      50.750000     NaN   28.750000           41.500000
# 50%     100.500000     NaN   36.000000           61.500000
# 75%     150.250000     NaN   49.000000           78.000000
# max     200.000000     NaN   70.000000          137.000000
#
#         Spending Score (1-100)
# count               200.000000
# unique                     NaN
# top                        NaN
# freq                       NaN
# mean                 50.200000
# std                  25.823522
# min                   1.000000
# 25%                  34.750000
# 50%                  50.000000
# 75%                  73.000000
# max                  99.000000

# %% [markdown]
# ## Filter Only Numerical Data

# %%
csv_data.describe(exclude=["O"])
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
csv_data.isnull().values.any()
# Out:
# False

# %%
csv_data_baru = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/shopping_data_missingvalue.csv")
csv_data_baru
# Out:
#      CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  19.0                15.0                    39.0
# 1             2    Male   NaN                15.0                    81.0
# 2             3  Female  20.0                 NaN                     6.0
# 3             4  Female  23.0                16.0                    77.0
# 4             5  Female  31.0                17.0                     NaN
# ..          ...     ...   ...                 ...                     ...
# 195         196  Female  35.0               120.0                    79.0
# 196         197  Female  45.0               126.0                    28.0
# 197         198    Male  32.0               126.0                    74.0
# 198         199    Male  32.0               137.0                    18.0
# 199         200    Male  30.0               137.0                    83.0
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Check Null/NaN Data

# %%
csv_data_baru.isnull().values.any()
# Out:
# True

# %% [markdown]
# ## Missing Value Data Solution
#
# ![image.png](data:image/png;base64,...)

# %%
csv_data_baru.mean()
# Out:
# <ipython-input-14-3967b5f12f43>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   csv_data_baru.mean()
# CustomerID                100.500000
# Age                        38.939698
# Annual Income (k$)         61.005051
# Spending Score (1-100)     50.489899
# dtype: float64

# %% [markdown]
# ## Adding Mean Value to Null/NaN Data (Imputation)

# %%
csv_data_baru.mean()
print("Dataset yang masih terdapat nilai kosong! :")
csv_data_baru.head(10)
# Out:
# Dataset yang masih terdapat nilai kosong! :
# <ipython-input-15-5b3f56703975>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   csv_data_baru.mean()
#    CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                15.0                    39.0
# 1           2    Male   NaN                15.0                    81.0
# 2           3  Female  20.0                 NaN                     6.0
# 3           4  Female  23.0                16.0                    77.0
# 4           5  Female  31.0                17.0                     NaN
# 5           6  Female  22.0                 NaN                    76.0
# 6           7  Female  35.0                18.0                     6.0
# 7           8  Female  23.0                18.0                    94.0
# 8           9    Male  64.0                19.0                     NaN
# 9          10  Female  30.0                19.0                    72.0

# %%
csv_data_baru_mean = csv_data_baru.fillna(csv_data_baru.mean())
print("Dataset yang sudah diproses Handling Missing Values dengan Mean :")
csv_data_baru_mean.head(10)
# Out:
# Dataset yang sudah diproses Handling Missing Values dengan Mean :
# <ipython-input-16-ead7f8c1b218>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   csv_data_baru_mean = csv_data_baru.fillna(csv_data_baru.mean())
#    CustomerID   Genre        Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.000000           15.000000               39.000000
# 1           2    Male  38.939698           15.000000               81.000000
# 2           3  Female  20.000000           61.005051                6.000000
# 3           4  Female  23.000000           16.000000               77.000000
# 4           5  Female  31.000000           17.000000               50.489899
# 5           6  Female  22.000000           61.005051               76.000000
# 6           7  Female  35.000000           18.000000                6.000000
# 7           8  Female  23.000000           18.000000               94.000000
# 8           9    Male  64.000000           19.000000               50.489899
# 9          10  Female  30.000000           19.000000               72.000000

# %% [markdown]
# ## Adding Median Value to Null/NaN Data (Imputation)

# %%
csv_data_baru.median()
print("Dataset yang masih terdapat nilai kosong! :")
csv_data_baru.head(10)
# Out:
# Dataset yang masih terdapat nilai kosong! :
# <ipython-input-17-3288691d28da>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   csv_data_baru.median()
#    CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                15.0                    39.0
# 1           2    Male   NaN                15.0                    81.0
# 2           3  Female  20.0                 NaN                     6.0
# 3           4  Female  23.0                16.0                    77.0
# 4           5  Female  31.0                17.0                     NaN
# 5           6  Female  22.0                 NaN                    76.0
# 6           7  Female  35.0                18.0                     6.0
# 7           8  Female  23.0                18.0                    94.0
# 8           9    Male  64.0                19.0                     NaN
# 9          10  Female  30.0                19.0                    72.0

# %%
csv_data_baru_median = csv_data_baru.fillna(csv_data_baru.median())
print("Dataset yang sudah diproses Handling Missing Values dengan Median :")
csv_data_baru_median.head(10)
# Out:
# Dataset yang sudah diproses Handling Missing Values dengan Median :
# <ipython-input-18-258ed63960be>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   csv_data_baru_median = csv_data_baru.fillna(csv_data_baru.median())
#    CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                15.0                    39.0
# 1           2    Male  36.0                15.0                    81.0
# 2           3  Female  20.0                62.0                     6.0
# 3           4  Female  23.0                16.0                    77.0
# 4           5  Female  31.0                17.0                    50.0
# 5           6  Female  22.0                62.0                    76.0
# 6           7  Female  35.0                18.0                     6.0
# 7           8  Female  23.0                18.0                    94.0
# 8           9    Male  64.0                19.0                    50.0
# 9          10  Female  30.0                19.0                    72.0

# %% [markdown]
# ## Data Normalization

# %% [markdown]
# ### MinMax
#
# Metode Min-Max merupakan metode yang cukup bisa dibayangkan karena termasuk metode normalisasi yang bersifat linier dengan data aslinya. Namun, metode ini bisa menyebabkan out of bound pada beberapa kasus.
#
# ![image.png](data:image/png;base64,...)
#
# Kenapa bisa terjadi out of bound? Out of Bound terjadi apabila ada data baru masuk, dimana data tersebut melebihi nilai maksimal atau nilai minimal dari data yang sudah ada. Secara otomatis, perhitungan yang berlaku pada data yang sudah diperoleh tadi harus diulangi lagi semuanya dengan data baru yang masuk atau data baru yang mempunyai nilai maksimal/minimum yang melebihi tadi tidak bisa diproses. Karena kekurangan inilah MinMax tidak cocok untuk analisa real time / evolving system. Dimungkinkan dalam kasus-kasus terjadi kasus out of bound pada MinMax.
#
# MinMax sangat dianjurkan untuk kasus-kasus berbasis time frame analisis dan forecasting. Perhitungan dari metode ini cukup mengurangi data yang asli dengan nilai minimal dari fitur tersebut, kemudian hasil tersebut dikalikan dari hasil pengurangan nilai maximal yang baru dengan nilai minimal yang baru dan kemudian dibagi dengan nilai max dan min data di setiap fitur terakhir ditambah dengan nilai min yang baru.

# %% [markdown]
# ## Z-Score
#
# Zscore adalah metode yang sering digunakan dalam berbagai penelitian berbasis data mining atau data science. Z-score merupakan metode normalisasi yang berdasarkan mean (nilai rata-rata) dan standard deviation (deviasi standar) dari data. Kenapa Z-Score sangat populer? Selain tidak banyak variabel yang diset dalam perhitungannya. Z-Score sangat dinamis dalam melakukan perhitungan normalisasi. Kelemahan dari Z-Score adalah prosesnya akan terulang lagi jika ada data baru yang masuk. Selain itu elemen yang dibutuhkan untuk perhitungan Z-Score juga membutuhkan proses yang cukup lama baik standar deviation ataupun rata-rata dari setiap kolom.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Decimal Scaling
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Softmax
#
# Softmax merupakan metode normalisasi pengembangan transformasi secara linier. Output range-nya adalah 0-1. Metode ini sangat berguna pada saat data yang ada melibatkan data outlier.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Sigmoid
#
# Sigmoidal merupakan metode normalization melakukan normalisasi data secara nonlinier ke dalam range -1 s/d 1 dengan menggunakan fungsi sigmoid. Metode ini sangat berguna pada saat data yang ada melibatkan data outlier. Data outlier adalah data yang keluar jauh dari jangkauan data lainnya
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

csv_data = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/shopping_data.csv")
array = csv_data.values
array
# Out:
# array([[1, 'Male', 19, 15, 39],
#        [2, 'Male', 21, 15, 81],
#        [3, 'Female', 20, 16, 6],
#        [4, 'Female', 23, 16, 77],
#        [5, 'Female', 31, 17, 40],
#        [6, 'Female', 22, 17, 76],
#        [7, 'Female', 35, 18, 6],
#        [8, 'Female', 23, 18, 94],
#        [9, 'Male', 64, 19, 3],
#        [10, 'Female', 30, 19, 72],
#        [11, 'Male', 67, 19, 14],
#        [12, 'Female', 35, 19, 99],
#        [13, 'Female', 58, 20, 15],
#        [14, 'Female', 24, 20, 77],
#        [15, 'Male', 37, 20, 13],
#        [16, 'Male', 22, 20, 79],
#        [17, 'Female', 35, 21, 35],
#        [18, 'Male', 20, 21, 66],
#        [19, 'Male', 52, 23, 29],
#        [20, 'Female', 35, 23, 98],
#        [21, 'Male', 35, 24, 35],
#        [22, 'Male', 25, 24, 73],
#        [23, 'Female', 46, 25, 5],
#        [24, 'Male', 31, 25, 73],
#        [25, 'Female', 54, 28, 14],
#        [26, 'Male', 29, 28, 82],
#        [27, 'Female', 45, 28, 32],
#        [28, 'Male', 35, 28, 61],
#        [29, 'Female', 40, 29, 31],
#        [30, 'Female', 23, 29, 87],
#        [31, 'Male', 60, 30, 4],
#        [32, 'Female', 21, 30, 73],
#        [33, 'Male', 53, 33, 4],
#        [34, 'Male', 18, 33, 92],
#        [35, 'Female', 49, 33, 14],
#        [36, 'Female', 21, 33, 81],
#        [37, 'Female', 42, 34, 17],
#        [38, 'Female', 30, 34, 73],
#        [39, 'Female', 36, 37, 26],
#        [40, 'Female', 20, 37, 75],
#        [41, 'Female', 65, 38, 35],
#        [42, 'Male', 24, 38, 92],
#        [43, 'Male', 48, 39, 36],
#        [44, 'Female', 31, 39, 61],
#        [45, 'Female', 49, 39, 28],
#        [46, 'Female', 24, 39, 65],
#        [47, 'Female', 50, 40, 55],
#        [48, 'Female', 27, 40, 47],
#        [49, 'Female', 29, 40, 42],
#        [50, 'Female', 31, 40, 42],
#        [51, 'Female', 49, 42, 52],
#        [52, 'Male', 33, 42, 60],
#        [53, 'Female', 31, 43, 54],
#        [54, 'Male', 59, 43, 60],
#        [55, 'Female', 50, 43, 45],
#        [56, 'Male', 47, 43, 41],
#        [57, 'Female', 51, 44, 50],
#        [58, 'Male', 69, 44, 46],
#        [59, 'Female', 27, 46, 51],
#        [60, 'Male', 53, 46, 46],
#        [61, 'Male', 70, 46, 56],
#        [62, 'Male', 19, 46, 55],
#        [63, 'Female', 67, 47, 52],
#        [64, 'Female', 54, 47, 59],
#        [65, 'Male', 63, 48, 51],
#        [66, 'Male', 18, 48, 59],
#        [67, 'Female', 43, 48, 50],
#        [68, 'Female', 68, 48, 48],
#        [69, 'Male', 19, 48, 59],
#        [70, 'Female', 32, 48, 47],
#        [71, 'Male', 70, 49, 55],
#        [72, 'Female', 47, 49, 42],
#        [73, 'Female', 60, 50, 49],
#        [74, 'Female', 60, 50, 56],
#        [75, 'Male', 59, 54, 47],
#        [76, 'Male', 26, 54, 54],
#        [77, 'Female', 45, 54, 53],
#        [78, 'Male', 40, 54, 48],
#        [79, 'Female', 23, 54, 52],
#        [80, 'Female', 49, 54, 42],
#        [81, 'Male', 57, 54, 51],
#        [82, 'Male', 38, 54, 55],
#        [83, 'Male', 67, 54, 41],
#        [84, 'Female', 46, 54, 44],
#        [85, 'Female', 21, 54, 57],
#        [86, 'Male', 48, 54, 46],
#        [87, 'Female', 55, 57, 58],
#        [88, 'Female', 22, 57, 55],
#        [89, 'Female', 34, 58, 60],
#        [90, 'Female', 50, 58, 46],
#        [91, 'Female', 68, 59, 55],
#        [92, 'Male', 18, 59, 41],
#        [93, 'Male', 48, 60, 49],
#        [94, 'Female', 40, 60, 40],
#        [95, 'Female', 32, 60, 42],
#        [96, 'Male', 24, 60, 52],
#        [97, 'Female', 47, 60, 47],
#        [98, 'Female', 27, 60, 50],
#        [99, 'Male', 48, 61, 42],
#        [100, 'Male', 20, 61, 49],
#        [101, 'Female', 23, 62, 41],
#        [102, 'Female', 49, 62, 48],
#        [103, 'Male', 67, 62, 59],
#        [104, 'Male', 26, 62, 55],
#        [105, 'Male', 49, 62, 56],
#        [106, 'Female', 21, 62, 42],
#        [107, 'Female', 66, 63, 50],
#        [108, 'Male', 54, 63, 46],
#        [109, 'Male', 68, 63, 43],
#        [110, 'Male', 66, 63, 48],
#        [111, 'Male', 65, 63, 52],
#        [112, 'Female', 19, 63, 54],
#        [113, 'Female', 38, 64, 42],
#        [114, 'Male', 19, 64, 46],
#        [115, 'Female', 18, 65, 48],
#        [116, 'Female', 19, 65, 50],
#        [117, 'Female', 63, 65, 43],
#        [118, 'Female', 49, 65, 59],
#        [119, 'Female', 51, 67, 43],
#        [120, 'Female', 50, 67, 57],
#        [121, 'Male', 27, 67, 56],
#        [122, 'Female', 38, 67, 40],
#        [123, 'Female', 40, 69, 58],
#        [124, 'Male', 39, 69, 91],
#        [125, 'Female', 23, 70, 29],
#        [126, 'Female', 31, 70, 77],
#        [127, 'Male', 43, 71, 35],
#        [128, 'Male', 40, 71, 95],
#        [129, 'Male', 59, 71, 11],
#        [130, 'Male', 38, 71, 75],
#        [131, 'Male', 47, 71, 9],
#        [132, 'Male', 39, 71, 75],
#        [133, 'Female', 25, 72, 34],
#        [134, 'Female', 31, 72, 71],
#        [135, 'Male', 20, 73, 5],
#        [136, 'Female', 29, 73, 88],
#        [137, 'Female', 44, 73, 7],
#        [138, 'Male', 32, 73, 73],
#        [139, 'Male', 19, 74, 10],
#        [140, 'Female', 35, 74, 72],
#        [141, 'Female', 57, 75, 5],
#        [142, 'Male', 32, 75, 93],
#        [143, 'Female', 28, 76, 40],
#        [144, 'Female', 32, 76, 87],
#        [145, 'Male', 25, 77, 12],
#        [146, 'Male', 28, 77, 97],
#        [147, 'Male', 48, 77, 36],
#        [148, 'Female', 32, 77, 74],
#        [149, 'Female', 34, 78, 22],
#        [150, 'Male', 34, 78, 90],
#        [151, 'Male', 43, 78, 17],
#        [152, 'Male', 39, 78, 88],
#        [153, 'Female', 44, 78, 20],
#        [154, 'Female', 38, 78, 76],
#        [155, 'Female', 47, 78, 16],
#        [156, 'Female', 27, 78, 89],
#        [157, 'Male', 37, 78, 1],
#        [158, 'Female', 30, 78, 78],
#        [159, 'Male', 34, 78, 1],
#        [160, 'Female', 30, 78, 73],
#        [161, 'Female', 56, 79, 35],
#        [162, 'Female', 29, 79, 83],
#        [163, 'Male', 19, 81, 5],
#        [164, 'Female', 31, 81, 93],
#        [165, 'Male', 50, 85, 26],
#        [166, 'Female', 36, 85, 75],
#        [167, 'Male', 42, 86, 20],
#        [168, 'Female', 33, 86, 95],
#        [169, 'Female', 36, 87, 27],
#        [170, 'Male', 32, 87, 63],
#        [171, 'Male', 40, 87, 13],
#        [172, 'Male', 28, 87, 75],
#        [173, 'Male', 36, 87, 10],
#        [174, 'Male', 36, 87, 92],
#        [175, 'Female', 52, 88, 13],
#        [176, 'Female', 30, 88, 86],
#        [177, 'Male', 58, 88, 15],
#        [178, 'Male', 27, 88, 69],
#        [179, 'Male', 59, 93, 14],
#        [180, 'Male', 35, 93, 90],
#        [181, 'Female', 37, 97, 32],
#        [182, 'Female', 32, 97, 86],
#        [183, 'Male', 46, 98, 15],
#        [184, 'Female', 29, 98, 88],
#        [185, 'Female', 41, 99, 39],
#        [186, 'Male', 30, 99, 97],
#        [187, 'Female', 54, 101, 24],
#        [188, 'Male', 28, 101, 68],
#        [189, 'Female', 41, 103, 17],
#        [190, 'Female', 36, 103, 85],
#        [191, 'Female', 34, 103, 23],
#        [192, 'Female', 32, 103, 69],
#        [193, 'Male', 33, 113, 8],
#        [194, 'Female', 38, 113, 91],
#        [195, 'Female', 47, 120, 16],
#        [196, 'Female', 35, 120, 79],
#        [197, 'Female', 45, 126, 28],
#        [198, 'Male', 32, 126, 74],
#        [199, 'Male', 32, 137, 18],
#        [200, 'Male', 30, 137, 83]], dtype=object)

# %%
X = array[:,2:5] #memisahkan fitur dari dataset. 
Y = array[:,0:1]  #memisahkan class dari dataset

dataset=pd.DataFrame({"Customer ID":array[:,0],"Gender":array[:,1],"Age":array[:,2],"Income":array[:,3],"Spending Score":array[:,4]})
print("dataset sebelum dinormalisasi :")
print(dataset.head(10))

min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0,1)) #inisialisasi normalisasi MinMax
data = min_max_scaler.fit_transform(X) #transformasi MinMax untuk fitur
dataset = pd.DataFrame({"Age":data[:,0],"Income":data[:,1],"Spending Score":data[:,2],"Customer ID":array[:,0],"Gender":array[:,1]})

print("dataset setelah dinormalisasi :")
print(dataset.head(10))
# Out:
# dataset sebelum dinormalisasi :
#   Customer ID  Gender Age Income Spending Score
# 0           1    Male  19     15             39
# 1           2    Male  21     15             81
# 2           3  Female  20     16              6
# 3           4  Female  23     16             77
# 4           5  Female  31     17             40
# 5           6  Female  22     17             76
# 6           7  Female  35     18              6
# 7           8  Female  23     18             94
# 8           9    Male  64     19              3
# 9          10  Female  30     19             72
# dataset setelah dinormalisasi :
#         Age    Income  Spending Score Customer ID  Gender
# 0  0.019231  0.000000        0.387755           1    Male
# 1  0.057692  0.000000        0.816327           2    Male
# 2  0.038462  0.008197        0.051020           3  Female
# 3  0.096154  0.008197        0.775510           4  Female
# 4  0.250000  0.016393        0.397959           5  Female
# 5  0.076923  0.016393        0.765306           6  Female
# 6  0.326923  0.024590        0.051020           7  Female
# 7  0.096154  0.024590        0.948980           8  Female
# 8  0.884615  0.032787        0.020408           9    Male
# 9  0.230769  0.032787        0.724490          10  Female
